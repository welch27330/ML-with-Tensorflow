# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv('C:/Users/baitin/Desktop/scottish_hills.csv')
x = dataframe.Height
y = dataframe.Latitude

# %%
plt.scatter(x,y)
plt.show()

# %%
from scipy.stats import linregress

# %%
stats = linregress(x,y)
m = stats.slope
b= stats.intercept

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

dataframe = pd.read_csv("C:/Users/baitin/Desktop/scottish_hills.csv")

x = dataframe.Height
y = dataframe.Latitude

stats = linregress(x, y)

m = stats.slope
b = stats.intercept

plt.scatter(x, y)
plt.plot(x, m * x + b, color="red")   # I've added a color argument here

plt.savefig("figure.png")

# Or you can use plt.show()
